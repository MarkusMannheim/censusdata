# %%
import pandas as pd

mesh_2021 = pd.read_excel(
    "./mesh2021.xlsx",
    sheet_name=1,
    header=6,
    skipfooter=5
)
mesh_2021
# Out:
#        MB_CODE_2021 MB_CATEGORY_NAME_2021  AREA_ALBERS_SQKM  Dwelling  Person  \
# 0       10000010000           Residential            0.0209        44      63
# 1       10000021000            Commercial            0.0829         0       0
# 2       10000022000            Commercial            0.0388         5       6
# 3       10000023000            Commercial            0.0254         4       4
# 4       10000024000           Residential            0.0376        15      22
# ...             ...                   ...               ...       ...     ...
# 59987   10644261000            Industrial            0.1180         5       8
# 59988   10644262000            Industrial            0.0161         6      12
# 59989   10644270000             Education            0.0022         0       0
# 59990   10644280000           Residential            0.0378        64     209
# 59991   10644290000             Education            0.0480         0       0
#
#        State
# 0          1
# ...
