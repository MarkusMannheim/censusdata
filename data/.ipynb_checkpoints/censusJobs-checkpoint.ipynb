# %%
import pandas as pd, numpy as np

jobs_1991 = pd.read_csv(
    "./jobs_1991.csv",
    index_col="occupation"
)
jobs_1991.sort_values("per cent", ascending=False).head(50)
# Out:
#                                                                                  category  \
# occupation
# sales assistants                                  salespersons & personal service workers
# miscellaneous labourers & related workers                     labourers & related workers
# numerical clerks                                                                   clerks
# specialist managers                                             managers & administrators
# stenographers & typists                                                            clerks
# school teachers                                                             professionals
# farmers & farm managers                                         managers & administrators
# road & rail transport drivers                         plant & machine operators & drivers
# business professionals                                                      professionals
# ...

# %%
jobs_2016 = pd.read_csv(
    "./jobs_2016.csv",
    index_col="occupation"
)
jobs_2016.sort_values("per cent", ascending=False).tail(50)
# Out:
#                                                                                 category  \
# occupation
# ict and telecommunications technicians                      technicians & trades workers
# professionals nfd                                                          professionals
# floor finishers and painting trades workers                 technicians & trades workers
# arts professionals                                                         professionals
# managers nfd                                                                    managers
# ict network and support professionals                                      professionals
# animal attendants and trainers, and shearers                technicians & trades workers
# delivery drivers                                           machinery operators & drivers
# miscellaneous factory process workers                                          labourers
# ...
