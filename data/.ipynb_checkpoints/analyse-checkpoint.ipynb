# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
from os import listdir
from os.path import isfile, join
sns.set(style="whitegrid", font_scale=1.25)

file_folder = "./root/data/SAL/AUS/"
files = listdir(file_folder)

suburb_list = pd.read_csv("./act_suburbs.csv", index_col="code")
suburb_list.index = ["SAL" + str(code) for code in suburb_list.index]
suburb_list.index.name = "code"
suburb_list

pd.read_csv(
    f"{file_folder}/{files[0]}",
    index_col="SAL_CODE_2021"
).T
# Out:
# SAL_CODE_2021               SAL10001  SAL10002  SAL10003  SAL10004  SAL10005  \
# Tot_P_M                           18      2067      2560       546        12
# Tot_P_F                           12      2129      2876       582        14
# Tot_P_P                           33      4200      5431      1127        21
# Age_0_4_yr_M                       0        85       150        31         0
# Age_0_4_yr_F                       0        95       129        35         0
# ...                              ...       ...       ...       ...       ...
# Count_psns_occ_priv_dwgs_F        10      2089      2714       570         7
# Count_psns_occ_priv_dwgs_P        22      4092      5156      1082        24
# Count_Persons_other_dwgs_M         0        52        99        11         0
# Count_Persons_other_dwgs_F         3        46       144        12         0
# Count_Persons_other_dwgs_P         5        99       240        16         0
#
# ...
